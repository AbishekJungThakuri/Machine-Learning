# %%
from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
x, y = load_iris(return_X_y=True)

# %%
models = {
    'KNN' : KNeighborsClassifier(n_neighbors=3),
    'Decision Tree' : DecisionTreeClassifier(max_depth=3,random_state=42),
    'Logistic Regression': LogisticRegression(max_iter=200)
}

# %%
from sklearn.model_selection import cross_val_score

# %%
best_model = None
best_accuracy = 0

import numpy as np
# Perform 5-fold cross-validation for each model
for name, model in models.items():
    accuracy = cross_val_score(model, x,y,cv=5)
    avg_accuracy = np.mean(accuracy)
    print(f"{name} Accuracy scores: {accuracy}")
    print(f"{name} Average Accuracy: {np.mean(avg_accuracy):.4f}\n")

    if avg_accuracy > best_accuracy:
        best_accuracy = avg_accuracy
        best_model = name
        
print(f"{best_model} is the best model with accuracy {best_accuracy}")
# Out:
# KNN Accuracy scores: [0.96666667 0.96666667 0.93333333 0.96666667 1.        ]
# KNN Average Accuracy: 0.9667
#
# Decision Tree Accuracy scores: [0.96666667 0.96666667 0.93333333 1.         1.        ]
# Decision Tree Average Accuracy: 0.9733
# Logistic Regression Accuracy scores: [0.96666667 1.         0.93333333 0.96666667 1.        ]
# Logistic Regression Average Accuracy: 0.9733
#
# Decision Tree is the best model with accuracy 0.9733333333333334
